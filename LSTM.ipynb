# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.utils import pad_sequences
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import Model, Input
from keras.layers import LSTM, Embedding, Dense
from keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("ner_dataset.csv", encoding="latin1")
data=data.fillna(method="ffill")
data.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
print("Unique words in corpus:",data['Word'].nunique())
print("Unique tags in corpus:",data['Tag'].nunique())
# Out:
# Unique words in corpus: 35178
# Unique tags in corpus: 17

# %%
words=list(set(data["Word"].values))
words.append("ENDPAD")
num_words=len(words)

# %%
tags=list(set(data["Tag"].values))
num_tags=len(tags)

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent=1
        self.data=data
        self.empty=False
        agg_func=lambda s:[(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                           s["POS"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped=self.data.groupby("Sentence #").apply(agg_func)
        self.sentences=[s for s in self.grouped]
    
    def get_next(self):
        try:
            s=self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent+=1
            return s
        except:
            return None

# %%
getter=SentenceGetter(data)
sentences=getter.sentences

# %%
sentences[0]
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %%
word2idx={w:i + 1 for i, w in enumerate(words)}
tag2idx={t:i for i, t in enumerate(tags)}

# %%
word2idx
# Out:
# {'among': 1,
#  'Dukeness': 2,
#  'northern-based': 3,
#  'Doaba': 4,
#  'squares': 5,
#  'Hospitals': 6,
#  'upcoming': 7,
#  'lending': 8,
#  'drained': 9,
#  'deploys': 10,
#  'bullet': 11,
#  'internally': 12,
#  'ACC': 13,
#  'Theo': 14,
#  'Ehsanul': 15,
#  'atrocity': 16,
#  'vivanews.com': 17,
#  'Boss': 18,
#  'Aleem': 19,
#  'aging': 20,
#  'Creator': 21,
#  'expand': 22,
#  'Works': 23,
#  "Sh'ite": 24,
#  'columnist': 25,
#  'coma': 26,
#  'Stallone': 27,
#  'civilian-to-civilian': 28,
#  'Prudhoe': 29,
#  'museum': 30,
#  'Libyan': 31,
#  'closures': 32,
#  'human': 33,
#  'richly': 34,
#  'NIGHTINGALE': 35,
#  'Itno': 36,
#  'pill': 37,
#  'Raad': 38,
#  'liberal': 39,
#  'conflict-resolution': 40,
#  'Nielsen': 41,
#  'dioxin': 42,
#  'lawlessness': 43,
#  'thirteenth': 44,
#  'horticulture': 45,
#  'double-digit': 46,
#  'non-export': 47,
#  'Community': 48,
#  'nails': 49,
#  'Eighteen': 50,
#  'coincided': 51,
#  'U.S.-proposed': 52,
#  'BIN': 53,
#  'payback': 54,
#  'herders': 55,
#  'practical': 56,
#  'undeclared': 57,
#  'Envious': 58,
#  'AKAEV': 59,
#  'Ben-Eliezer': 60,
#  'take-off': 61,
#  "Shi'te": 62,
#  'bring': 63,
#  'pre-2007': 64,
#  'stiffly': 65,
#  'barrel': 66,
#  'Canaveral': 67,
#  'stealing': 68,
#  'improving': 69,
#  'admiral': 70,
#  'Dow': 71,
#  'Orellana': 72,
#  'revive': 73,
#  'Guni': 74,
#  'two-thirds': 75,
#  'Inspections': 76,
#  'Brasilia': 77,
#  'dad': 78,
#  'intercepted': 79,
#  'pedestrians': 80,
#  'honor': 81,
#  'Montenegro': 82,
#  'Bikaner': 83,
#  'Duong': 84,
#  'Endeavor': 85,
#  'Habib': 86,
#  'gaining': 87,
#  'intermediary': 88,
#  'bulwark': 89,
#  '1844': 90,
#  'Hunter': 91,
#  'all-time': 92,
#  'separatist': 93,
#  'interplanetary': 94,
#  'reparations': 95,
#  'dancer': 96,
#  're-vote': 97,
#  'Kentung': 98,
#  'hostage-taker': 99,
#  'Dwayne': 100,
#  'Ricans': 101,
#  'replenish': 102,
#  'likes': 103,
#  'WOLF': 104,
#  'risk-management': 105,
#  'trout': 106,
#  'break-in': 107,
#  'pro-Taliban': 108,
#  '1923': 109,
#  'Voting': 110,
#  'arrived': 111,
#  'chess': 112,
#  'watches': 113,
#  'Birthday': 114,
#  'Tiananmen': 115,
#  'wont': 116,
#  'assessed': 117,
#  'picture': 118,
#  'Thirty-three': 119,
#  'Martinin': 120,
#  'Duaik': 121,
#  'Bugti': 122,
#  'Hungary': 123,
#  '173': 124,
#  'Kapustin': 125,
#  'Amazon.com': 126,
#  'Tidjane': 127,
#  'Board': 128,
#  'drug-combination': 129,
#  'genre': 130,
#  'Rashtriya': 131,
#  'semi-annual': 132,
#  '13.625': 133,
#  'hinge': 134,
#  'housed': 135,
#  'state-radio': 136,
#  'machetes': 137,
#  'Baku-Tbilisi-Ceyhan': 138,
#  'buying': 139,
#  'trillions': 140,
#  'stupid': 141,
#  'Cross': 142,
#  'sack': 143,
#  'wreaths': 144,
#  'career-best': 145,
#  'Branislav': 146,
#  'Moreover': 147,
#  'spy': 148,
#  'Esa': 149,
#  'opium-producing': 150,
#  'overruled': 151,
#  'furnish': 152,
#  'inflammation': 153,
#  'compressed': 154,
#  '51-year-old': 155,
#  'quotations': 156,
#  'enraged': 157,
#  'short-wave': 158,
#  'Albert': 159,
#  'SAFA': 160,
#  'smooth': 161,
#  'dare': 162,
#  'insiders': 163,
#  'flooding': 164,
#  'MENA': 165,
#  'Hajan': 166,
#  'Down': 167,
#  'shortened': 168,
#  'Eckhard': 169,
#  'Denisov': 170,
#  'kick-off': 171,
#  'pelt': 172,
#  'Lustiger': 173,
#  'Communication': 174,
#  'golf': 175,
#  'Azhari': 176,
#  '9.625': 177,
#  'inhabit': 178,
#  'Colts': 179,
#  'Tupolev': 180,
#  'involves': 181,
#  'vegetation': 182,
#  'resolute': 183,
#  'breach': 184,
#  'Tal': 185,
#  'loyalists': 186,
#  'Dhangadi': 187,
#  'Ambassador': 188,
#  'feud': 189,
#  '1907': 190,
#  'Antoin': 191,
#  'Swords': 192,
#  'wallets': 193,
#  'Aiko': 194,
#  'Fitzpatrick': 195,
#  'wallet': 196,
#  'Navarro-Valls': 197,
#  'canister': 198,
#  'CPSC': 199,
#  'insistence': 200,
#  'Powers': 201,
#  'Awards': 202,
#  'Shame': 203,
#  'Mugabe': 204,
#  'Cyclone': 205,
#  'Harkleroad': 206,
#  'disapproval': 207,
#  '267': 208,
#  '387': 209,
#  'fertile': 210,
#  'shall': 211,
#  'blankets': 212,
#  'rowing': 213,
#  'charitable': 214,
#  'fence': 215,
#  'Parish': 216,
#  'they': 217,
#  '1776': 218,
#  'Burge': 219,
#  'Sanjaya': 220,
#  '4,20,000': 221,
#  'yield': 222,
#  'Boroujerdi': 223,
#  'organizer': 224,
#  'commandos': 225,
#  'Christian': 226,
#  'crooner': 227,
#  'settle': 228,
#  'Jihad': 229,
#  'Owen': 230,
#  'Crozet': 231,
#  'Canal': 232,
#  'murders': 233,
#  'HKD': 234,
#  'makers': 235,
#  'Helicopter': 236,
#  'Louisiana': 237,
#  'jump-start': 238,
#  'brewing': 239,
#  'Poupard': 240,
#  '12,012': 241,
#  'Aksel': 242,
#  'Pacers': 243,
#  'ulcers': 244,
#  'then-President': 245,
#  'hardest-hit': 246,
#  'publicized': 247,
#  'promises': 248,
#  'underwater': 249,
#  'Brigade': 250,
#  'crystal': 251,
#  'Lance': 252,
#  'dead': 253,
#  'tuition': 254,
#  'Congressional': 255,
#  'Piano': 256,
#  'dug': 257,
#  'kill': 258,
#  'rocketed': 259,
#  'CONVENTION': 260,
#  'Sanclemente': 261,
#  'disobedience': 262,
#  'Hindu': 263,
#  'review': 264,
#  '28.25': 265,
#  'Advisors': 266,
#  'grasped': 267,
#  'objectivity': 268,
#  'Negroponte': 269,
#  'registry': 270,
#  'Bangladesh': 271,
#  'robots': 272,
#  'belts': 273,
#  'stabilizing': 274,
#  '28-member': 275,
#  'Mbeki': 276,
#  'judgments': 277,
#  'Costeira': 278,
#  'alleges': 279,
#  'creativity': 280,
#  'mistreating': 281,
#  'cordoned': 282,
#  'chassis': 283,
#  'concerted': 284,
#  'Afghan-based': 285,
#  'warplanes': 286,
#  'two-hour': 287,
#  'Vaziri-Hamaneh': 288,
#  'five-match': 289,
#  'encountering': 290,
#  'Salik': 291,
#  'prefers': 292,
#  'czar': 293,
#  'Lek': 294,
#  'Mirnyi': 295,
#  '300-member': 296,
#  'seminar': 297,
#  'module': 298,
#  '10-meter': 299,
#  'bullet-ridden': 300,
#  'foments': 301,
#  'power-': 302,
#  'Angola': 303,
#  'tracts': 304,
#  'Howell': 305,
#  'destination': 306,
#  'over-interpreted': 307,
#  'bust': 308,
#  'minimize': 309,
#  'edged': 310,
#  'volumes': 311,
#  'Dizzy': 312,
#  'prospects': 313,
#  'worn': 314,
#  'Rebelde': 315,
#  'Wanted': 316,
#  'al-Arab': 317,
#  '221': 318,
#  'USSR': 319,
#  'affirming': 320,
#  'Sardinia': 321,
#  'Scythians': 322,
#  'characters': 323,
#  '11-style': 324,
#  'truss': 325,
#  'quarreled': 326,
#  'Benin': 327,
#  'chrome': 328,
#  'Arsenal': 329,
#  'Bangladeshi': 330,
#  'entire': 331,
#  'Samples': 332,
#  'Supreme': 333,
#  'HMS': 334,
#  'rehabilitation': 335,
#  'bastion': 336,
#  'self-sufficiency': 337,
#  'ladders': 338,
#  'Kris': 339,
#  'Sinhalese': 340,
#  'closure': 341,
#  'hog': 342,
#  'prevent': 343,
#  'galaxies': 344,
#  'Alpine': 345,
#  'provision': 346,
#  'Cathedral': 347,
#  'jailhouse': 348,
#  'unverifiable': 349,
#  'Ghana': 350,
#  'implications': 351,
#  'polarize': 352,
#  'Jakob': 353,
#  'offending': 354,
#  'Hardline': 355,
#  'Treaty': 356,
#  'shambles': 357,
#  'bicycle': 358,
#  'pop': 359,
#  'choosing': 360,
#  'retaking': 361,
#  'sponsored': 362,
#  'Hawaii': 363,
#  'insurgent': 364,
#  'firmly': 365,
#  'earthquakes': 366,
#  'prep': 367,
#  'incubator': 368,
#  'Kesbir': 369,
#  'co-sponsoring': 370,
#  'immunization': 371,
#  'Halliburton': 372,
#  'codes': 373,
#  'Asafa': 374,
#  'Morelos': 375,
#  '71.79': 376,
#  'medicines': 377,
#  'Miami-based': 378,
#  'assumed': 379,
#  'Superhighway': 380,
#  'second-ranked': 381,
#  'Barbey': 382,
#  'Sinn': 383,
#  'saints': 384,
#  'Huthi': 385,
#  '1850': 386,
#  'maximize': 387,
#  'Chiapas': 388,
#  'mujahedin': 389,
#  'GONSALVES': 390,
#  'vanquished': 391,
#  'Mihtarlam': 392,
#  'Champion': 393,
#  'Shafi': 394,
#  'negotiating': 395,
#  'garments': 396,
#  'Mindaoudou': 397,
#  'village': 398,
#  'comptroller': 399,
#  'shifts': 400,
#  'lodge': 401,
#  'Espirito': 402,
#  'talked': 403,
#  'Vishnevskaya': 404,
#  'Wam': 405,
#  'ball-point': 406,
#  'deep-sea': 407,
#  'voting': 408,
#  'Maroney': 409,
#  'dislocation': 410,
#  'polarized': 411,
#  'poverty-stricken': 412,
#  'non-contracted': 413,
#  'Priscilla': 414,
#  'Mannar': 415,
#  'Irbil': 416,
#  'Philippoussis': 417,
#  'Khaled': 418,
#  'Lutfullah': 419,
#  'Izmir': 420,
#  'Electric': 421,
#  '737-800': 422,
#  'Schoch': 423,
#  'withdraw': 424,
#  'translations': 425,
#  'NKURUNZIZA': 426,
#  'Nigerla': 427,
#  'Unions': 428,
#  'seller': 429,
#  'Celebrations': 430,
#  'co-finance': 431,
#  'Boer': 432,
#  'Deposed': 433,
#  'cans': 434,
#  'outlets': 435,
#  'integrity': 436,
#  'depicting': 437,
#  'Saqib': 438,
#  'Ga.': 439,
#  'Kubba': 440,
#  'Claus': 441,
#  'fortunate': 442,
#  'detective': 443,
#  'Exporters': 444,
#  'reassure': 445,
#  'wandering': 446,
#  'glasnost': 447,
#  'Domenici': 448,
#  'coal': 449,
#  'Live': 450,
#  'Another': 451,
#  'whenever': 452,
#  'remoteness': 453,
#  'mirror': 454,
#  'Valero': 455,
#  'sentiment': 456,
#  'Committees': 457,
#  'snapshot': 458,
#  'circumstances': 459,
#  'Durango': 460,
#  'underdevelopment': 461,
#  'foreigners': 462,
#  'Atal': 463,
#  'confirming': 464,
#  'Bus': 465,
#  'pre-Olympic': 466,
#  'Hugh': 467,
#  'approaching': 468,
#  'outlined': 469,
#  'Sicily': 470,
#  'Chad-Sudan': 471,
#  'Sekou': 472,
#  'rises': 473,
#  'doing': 474,
#  'playmaker': 475,
#  'Genetic': 476,
#  'heel': 477,
#  'runoff': 478,
#  'worshipped': 479,
#  'Gheorghe': 480,
#  'offseason': 481,
#  'health-care': 482,
#  'Dejan': 483,
#  'vegetables': 484,
#  'miscalculated': 485,
#  'Patan': 486,
#  'anti-Semitic': 487,
#  'Disputed': 488,
#  'tolerance': 489,
#  'Kopra': 490,
#  'dilemma': 491,
#  'Iranian-Cuban': 492,
#  'servants': 493,
#  '87.61': 494,
#  'Fadela': 495,
#  'Junaid': 496,
#  'insight': 497,
#  'gymnast': 498,
#  'entice': 499,
#  'Atambayev': 500,
#  'cheat': 501,
#  'surfboard': 502,
#  'wager': 503,
#  'pall': 504,
#  'faculty': 505,
#  'parity': 506,
#  '240': 507,
#  'Tuvalu': 508,
#  'Shaukat': 509,
#  'presents': 510,
#  'string': 511,
#  'Hong-Kong-based': 512,
#  'fastest': 513,
#  'advantages': 514,
#  'assortment': 515,
#  'guardedly': 516,
#  'flash': 517,
#  'Hussein': 518,
#  'Marinellis': 519,
#  'collaborators': 520,
#  'wooden': 521,
#  'seismological': 522,
#  'Steele': 523,
#  'Albright': 524,
#  'Oman': 525,
#  'Rheinland-Pfalz': 526,
#  'Hulya': 527,
#  '2.5-year': 528,
#  'loosed': 529,
#  'co-conspirators': 530,
#  'inauguration': 531,
#  'Katsina': 532,
#  'Festival': 533,
#  'worrisome': 534,
#  'equally': 535,
#  'Index': 536,
#  'Notice': 537,
#  'rabbi': 538,
#  'Lankans': 539,
#  'community-owned': 540,
#  'statehood': 541,
#  'demining': 542,
#  'align': 543,
#  'chapters': 544,
#  'earning': 545,
#  'Blabague': 546,
#  'subsided': 547,
#  'profitable': 548,
#  'drafting': 549,
#  'Tegua': 550,
#  'single-party': 551,
#  'Mashal': 552,
#  'flagship': 553,
#  'hearty': 554,
#  'universe': 555,
#  'might': 556,
#  'Yung-woo': 557,
#  'minibus': 558,
#  'evaded': 559,
#  'south-southeast': 560,
#  'indifferent': 561,
#  'wiped': 562,
#  'Amil': 563,
#  'jobs': 564,
#  'Payenda': 565,
#  '17th-century': 566,
#  'Hearts': 567,
#  'jewelers': 568,
#  'Try': 569,
#  'American-run': 570,
#  'parole': 571,
#  'education': 572,
#  'speculation': 573,
#  'compassion': 574,
#  'out-of-work': 575,
#  'Bernales': 576,
#  'attorneys': 577,
#  'States': 578,
#  'Hailie': 579,
#  'permanent': 580,
#  'Nirvana': 581,
#  'motivation': 582,
#  'beggars': 583,
#  'mourned': 584,
#  'Senior': 585,
#  'Weightlifting': 586,
#  'Al-Adha': 587,
#  'vaccine': 588,
#  'Rajasthan': 589,
#  'Chiapolino': 590,
#  'RAVEN': 591,
#  'Justine': 592,
#  'winner': 593,
#  'economical': 594,
#  'generosity': 595,
#  'Afghan-Pakistan': 596,
#  'Hyundai': 597,
#  'Agu': 598,
#  'praised': 599,
#  'sentiments': 600,
#  'Band': 601,
#  'territorial': 602,
#  'defend': 603,
#  'expatriate': 604,
#  'Savin': 605,
#  'wrought': 606,
#  'penalize': 607,
#  'Navarro': 608,
#  'devil': 609,
#  'US-Cambodia': 610,
#  'stirred': 611,
#  'Inaugural': 612,
#  'man-made': 613,
#  'finalists': 614,
#  'Beitenu': 615,
#  'victimize': 616,
#  'Pharrell': 617,
#  'leaving': 618,
#  'reconcilation': 619,
#  'contributed': 620,
#  'workforce': 621,
#  'plan': 622,
#  'Suu': 623,
#  'fresh': 624,
#  'sincerity': 625,
#  'Seal': 626,
#  'Bertie': 627,
#  'personnel': 628,
#  'Faisal': 629,
#  'accompanied': 630,
#  'exposure': 631,
#  'plotting': 632,
#  'mainstays': 633,
#  'multi-year': 634,
#  'Sunni-dominated': 635,
#  'Gedi': 636,
#  'Khurul': 637,
#  'substantially': 638,
#  'rendered': 639,
#  'Andes': 640,
#  'Weekly': 641,
#  'Sherpa': 642,
#  'lantern': 643,
#  'incumbent': 644,
#  'Bremer': 645,
#  'gather': 646,
#  '4,000': 647,
#  '124': 648,
#  'rapid-reaction': 649,
#  'Kian': 650,
#  'unexplored': 651,
#  '73': 652,
#  'beached': 653,
#  'tempered': 654,
#  'Cermak': 655,
#  'Stone': 656,
#  'Oleksander': 657,
#  'defended': 658,
#  'Estefan': 659,
#  'overweight': 660,
#  'Duchess': 661,
#  'reeling': 662,
#  'Nath': 663,
#  'jeopardizes': 664,
#  'slandered': 665,
#  'succeeds': 666,
#  '232nd': 667,
#  'Cathay': 668,
#  'Moradi': 669,
#  'Elias': 670,
#  'Shawkat': 671,
#  'Sarah': 672,
#  'alone': 673,
#  'part': 674,
#  'historical': 675,
#  'boasting': 676,
#  'chin': 677,
#  'same': 678,
#  'Ottawa': 679,
#  'optimism': 680,
#  '175-run': 681,
#  'annualized': 682,
#  'Airbus': 683,
#  'Leaders': 684,
#  'accrue': 685,
#  're-training': 686,
#  'senate': 687,
#  'kidnapper': 688,
#  'elephant': 689,
#  'Petra': 690,
#  'hard': 691,
#  'complains': 692,
#  'Jung': 693,
#  'python': 694,
#  'Equatoria': 695,
#  'statue': 696,
#  'liner': 697,
#  'Dawa': 698,
#  'Bekasi': 699,
#  'revolution': 700,
#  'Guerrilla': 701,
#  'Clemens': 702,
#  'hardcourts': 703,
#  'Timex': 704,
#  'deplored': 705,
#  'Deuba': 706,
#  'stab': 707,
#  'comprised': 708,
#  'blessing': 709,
#  'Colon': 710,
#  'intentionally': 711,
#  'unfriendly': 712,
#  'Antananarivo': 713,
#  'price-per-carat': 714,
#  'Claudio': 715,
#  'regaining': 716,
#  'goaltender': 717,
#  'Latest': 718,
#  'cooled': 719,
#  'Chrysostomos': 720,
#  'Kristofferson': 721,
#  'Nouri': 722,
#  'births': 723,
#  'officers': 724,
#  'Palocci': 725,
#  'conference': 726,
#  'explosively': 727,
#  'Excellence': 728,
#  'tortured': 729,
#  'sterility': 730,
#  'millimeter': 731,
#  'Awe': 732,
#  'preparedness': 733,
#  'Mohamud': 734,
#  'Bhaikaji': 735,
#  'trampling': 736,
#  'Derbez': 737,
#  'mining': 738,
#  'sport': 739,
#  'Ceyhan': 740,
#  'praising': 741,
#  'waking': 742,
#  'processed': 743,
#  'Reggio': 744,
#  'Deauville': 745,
#  'pre-marked': 746,
#  'Northern': 747,
#  'customer': 748,
#  'lamented': 749,
#  'anti-Japanese': 750,
#  'Interviewed': 751,
#  'Rama': 752,
#  'SSR': 753,
#  'Omaha': 754,
#  'multi-target': 755,
#  'Joschka': 756,
#  '30,000': 757,
#  'Saints': 758,
#  'Prophet': 759,
#  'smoking': 760,
#  'Sinak': 761,
#  'circled': 762,
#  'English-speaking': 763,
#  'Polish': 764,
#  'Empire': 765,
#  'hounds': 766,
#  'pro-Democracy': 767,
#  'Zaid': 768,
#  'Qalat': 769,
#  'Tetiana': 770,
#  'Barrios': 771,
#  'Jesus': 772,
#  'Swedes': 773,
#  'Take': 774,
#  'methanol': 775,
#  'Sebastiao': 776,
#  'imbalance': 777,
#  'legitimizing': 778,
#  'Indianapolis': 779,
#  'heaven': 780,
#  'strikers': 781,
#  'Fatmir': 782,
#  'USDA': 783,
#  'Trabzon': 784,
#  'wind-assisted': 785,
#  'Bernal': 786,
#  'micro-miniature': 787,
#  'kilted': 788,
#  'Ivorian': 789,
#  'typhoid': 790,
#  'Moscow-led': 791,
#  'modifications': 792,
#  'three-crown': 793,
#  'Delamere': 794,
#  'us': 795,
#  'Cargolux': 796,
#  'Ukrainian': 797,
#  'be': 798,
#  'Rodrigues': 799,
#  'possessing': 800,
#  'Jalal': 801,
#  'university': 802,
#  'Dutch-Shell': 803,
#  'waterway': 804,
#  'Fig-Tree': 805,
#  'Recent': 806,
#  'Female': 807,
#  'jesting': 808,
#  'simulation': 809,
#  'thereof': 810,
#  '195': 811,
#  'absorbs': 812,
#  'Alishar': 813,
#  'churned': 814,
#  'adultery': 815,
#  'Liwei': 816,
#  'Rock-throwing': 817,
#  'Bollea': 818,
#  'Dahuk': 819,
#  'brew': 820,
#  'Robitaille': 821,
#  'testing': 822,
#  'invented': 823,
#  'Rudolph': 824,
#  'Somaliland': 825,
#  'Newspapers': 826,
#  'ventures': 827,
#  'crumbled': 828,
#  'Moderate': 829,
#  'situations': 830,
#  'Meuli': 831,
#  'presently': 832,
#  'Arms': 833,
#  'Rape': 834,
#  'organizing': 835,
#  'auctioned': 836,
#  'suing': 837,
#  'backlash': 838,
#  'Ramaroson': 839,
#  'segments': 840,
#  'Bouteflika': 841,
#  'Sandagiri': 842,
#  '16.8': 843,
#  'vast': 844,
#  'sweaters': 845,
#  'Daimler': 846,
#  'well-known': 847,
#  'environment-friendly': 848,
#  'Adaado': 849,
#  'barricade': 850,
#  'discourage': 851,
#  'grandson': 852,
#  'Wardheer': 853,
#  'Am': 854,
#  'Navy': 855,
#  'Espersen': 856,
#  'Suhaila': 857,
#  'pigs': 858,
#  'televisions': 859,
#  'Kaesong': 860,
#  'obsessed': 861,
#  'Middlesbrough': 862,
#  'Fiji': 863,
#  'Revava': 864,
#  'IMF-led': 865,
#  '71,000': 866,
#  'good-bye': 867,
#  '155': 868,
#  'freestyle': 869,
#  'unprofessional': 870,
#  'Diwaniyah': 871,
#  'overtook': 872,
#  'exacerbated': 873,
#  'Blizzard-like': 874,
#  'Alaina': 875,
#  'prison-like': 876,
#  'rejecting': 877,
#  'Zinder': 878,
#  'marsh': 879,
#  'Neve': 880,
#  'reputed': 881,
#  'Taif': 882,
#  'rich': 883,
#  'servicing': 884,
#  'dwell': 885,
#  'Call': 886,
#  'soils': 887,
#  'Preaching': 888,
#  'hardliner': 889,
#  'logical': 890,
#  'Marit': 891,
#  '99.3': 892,
#  'Haris': 893,
#  'heart-related': 894,
#  'Babar': 895,
#  'vulgar': 896,
#  'sudden': 897,
#  'negligent': 898,
#  'in': 899,
#  'Paktika': 900,
#  'person': 901,
#  'specializes': 902,
#  '534': 903,
#  'Ohanesian': 904,
#  'energy-saving': 905,
#  'attribute': 906,
#  'Maru': 907,
#  'arts': 908,
#  'Belkhadem': 909,
#  'Olusegan': 910,
#  'vehicle': 911,
#  'Amended': 912,
#  '21,000': 913,
#  '1950': 914,
#  'Kogelo': 915,
#  'substances': 916,
#  '5-million': 917,
#  'confidence': 918,
#  'Llagostera': 919,
#  'long-term': 920,
#  'halting': 921,
#  'understating': 922,
#  'released': 923,
#  'Higüey': 924,
#  'countless': 925,
#  'Tamil-majority': 926,
#  'Selected': 927,
#  'metal': 928,
#  'Artemisia': 929,
#  '19,000': 930,
#  'wept': 931,
#  'Coups': 932,
#  'martial': 933,
#  'stepped': 934,
#  '10-month-old': 935,
#  'reprisal': 936,
#  'pig-borne': 937,
#  'farthest': 938,
#  'Iraqis': 939,
#  'fame': 940,
#  'reaffirms': 941,
#  'Roed-Larsen': 942,
#  'advising': 943,
#  'commuter': 944,
#  'twins': 945,
#  'flying': 946,
#  'nesting': 947,
#  'democratizing': 948,
#  'engaging': 949,
#  'Lent': 950,
#  'profiled': 951,
#  '756': 952,
#  'Mitofsky': 953,
#  'businessman': 954,
#  'Sino-American': 955,
#  'perestroika': 956,
#  'Mazdzer': 957,
#  'feeding': 958,
#  'Mil': 959,
#  'Shepherds': 960,
#  'whir': 961,
#  'Tearfund': 962,
#  'enslaved': 963,
#  'long-lasting': 964,
#  '1941': 965,
#  'harmful': 966,
#  'cheeks': 967,
#  'amend': 968,
#  'Ahronot': 969,
#  'al-Mabhouh': 970,
#  'pullouts': 971,
#  'Gatemouth': 972,
#  'Khalil': 973,
#  'Russian-speaking': 974,
#  'know': 975,
#  'allowed': 976,
#  'colonial': 977,
#  'liquidity': 978,
#  'solar-electric': 979,
#  'pre-tax': 980,
#  'Iwan': 981,
#  'Jac': 982,
#  'Pinerolo': 983,
#  'Hamlin': 984,
#  'summoned': 985,
#  'appeal': 986,
#  'Bolt': 987,
#  'Dutch-born': 988,
#  'al-Siddiq': 989,
#  'Amur': 990,
#  'up': 991,
#  'Dinamo': 992,
#  'Guangdong': 993,
#  'foiled': 994,
#  '86-year-old': 995,
#  'at-large': 996,
#  'Working': 997,
#  'Sao': 998,
#  'Dianne': 999,
#  'Inarritu': 1000,
#  ...}

# %%
max_len=50
X=[[word2idx[w[0]] for w in s] for s in sentences]
X=pad_sequences(maxlen=max_len, sequences=X, padding="post", value=num_words-1)
y=[[tag2idx[w[2]] for w in s] for s in sentences]
y=pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

# %%
x_train, x_test, y_train, y_test=train_test_split(X, y, test_size=0.25, random_state=1)

# %%
input_word=Input(shape=(max_len,))
model=Embedding(input_dim=num_words, output_dim=50, input_length=max_len)(input_word)
model=SpatialDropout1D(0.1)(model)
model=Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)
out=TimeDistributed(Dense(num_tags, activation="softmax"))(model)
model=Model(input_word, out)
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50)]              0
#
#  embedding (Embedding)       (None, 50, 50)            1758950
#
#  spatial_dropout1d (SpatialD  (None, 50, 50)           0
#  ropout1D)
#
#  bidirectional (Bidirectiona  (None, 50, 200)          120800
#  l)
#
#  time_distributed (TimeDistr  (None, 50, 17)           3417
#  ibuted)
#
# =================================================================
# Total params: 1,883,167
# Trainable params: 1,883,167
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
chkpt=ModelCheckpoint("model_weights.h5", monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=True, mode='min')
early_stopping=EarlyStopping(monitor='val_accuracy', min_delta=0, patience=1, verbose=0, mode='max', baseline=None, restore_best_weights=False)
history=model.fit(x=x_train, y=y_train, validation_data=(x_test,y_test), batch_size=32, epochs=5, verbose=1)
# Out:
# Epoch 1/5
# 1125/1125 [==============================] - 390s 340ms/step - loss: 0.1837 - accuracy: 0.9578 - val_loss: 0.0689 - val_accuracy: 0.9804
# Epoch 2/5
# 1125/1125 [==============================] - 378s 336ms/step - loss: 0.0522 - accuracy: 0.9846 - val_loss: 0.0526 - val_accuracy: 0.9844
# Epoch 3/5
# 1125/1125 [==============================] - 376s 334ms/step - loss: 0.0374 - accuracy: 0.9885 - val_loss: 0.0485 - val_accuracy: 0.9855
# Epoch 4/5
# 1125/1125 [==============================] - 370s 329ms/step - loss: 0.0307 - accuracy: 0.9903 - val_loss: 0.0483 - val_accuracy: 0.9859
# Epoch 5/5
# 1125/1125 [==============================] - 371s 329ms/step - loss: 0.0262 - accuracy: 0.9915 - val_loss: 0.0494 - val_accuracy: 0.9860

# %%
model.evaluate(x_test, y_test)
# Out:
# 375/375 [==============================] - 13s 32ms/step - loss: 2.8306 - accuracy: 0.0141
# [2.8306338787078857, 0.014075062237679958]

# %%
i=np.random.randint(0, x_test.shape[0]) 
p=model.predict(np.array([x_test[i]]))
p=np.argmax(p, axis=-1)
y_true = y_test[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" *30)
for w, true, pred in zip(x_test[i], y_true, p[0]):
    print("{:15}{}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# 1/1 [==============================] - 0s 405ms/step
# Word           True 	 Pred
#
# ------------------------------
# Afghan         B-gpe	I-geo
# officials      O	I-geo
# say            O	I-geo
# at             O	I-per
# least          O	I-per
# 29             O	B-tim
# suspected      O	I-per
# Taleban        B-org	I-per
# insurgents     O	I-per
# have           O	I-per
# been           O	I-per
# killed         O	I-per
# in             O	I-per
# clashes        O	B-geo
# with           O	B-geo
# NATO           B-org	B-geo
# and            O	I-per
# Afghan         B-gpe	I-per
# forces         O	I-per
# in             O	I-per
# two            O	I-per
# southern       O	I-per
# provinces      O	I-eve
# .              O	I-eve
# Ibos           O	I-per
# Ibos           O	I-per
# Ibos           O	I-per
# Ibos           O	I-geo
# Ibos           O	I-geo
# Ibos           O	I-geo
# Ibos           O	I-geo
# Ibos           O	I-geo
# Ibos           O	I-geo
# Ibos           O	I-geo
# Ibos           O	I-geo
# Ibos           O	I-geo
# Ibos           O	I-geo
# Ibos           O	I-geo
# Ibos           O	I-geo
# Ibos           O	I-geo
# Ibos           O	I-geo
# Ibos           O	B-per
# Ibos           O	B-per
# Ibos           O	B-per
# Ibos           O	B-per
# Ibos           O	B-per
# Ibos           O	B-per
# Ibos           O	B-per
# Ibos           O	B-per
# Ibos           O	B-per
